# %% [markdown]
# # ECE 570: Assignment Uploader
#
# Note:
# The file helps generate html version of your ipynb file.

# %% [markdown]
# # Mount your drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Change the `your_ipynb_file_dir` to the exact path of your jupyter notebook.

# %%
def preprocess(dir):
    # To deal with the error when there is [] in the path
    dir.replace('[','[[]')
    dir.replace(']','[]]')
    return dir

########################        YOUR CODE        ##########################
your_ipynb_file_dir = '/content/drive/MyDrive/ECE 57000/Assignment-4/Assignment_04_Exercise' # Example: '/content/drive/MyDrive/ECE570/Assignment_03_Exercise.ipynb'
########################      END YOUR CODE      ##########################

# !jupyter nbconvert --to html '{preprocess(your_ipynb_file_dir)}'
# Out:
# [NbConvertApp] Converting notebook /content/drive/MyDrive/ECE 57000/Assignment-4/Assignment_04_Exercise.ipynb to html
# [NbConvertApp] Writing 523820 bytes to /content/drive/MyDrive/ECE 57000/Assignment-4/Assignment_04_Exercise.html

# %% [markdown]
# # There should be a html file generated in the same directory as your ipynb notebook. Download and then open that html file using Chrome and select Print and save as pdf.
